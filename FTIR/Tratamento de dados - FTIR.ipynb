# %% [markdown]
# # Tratamento de dados - FTIR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_asu = pd.read_fwf("FTIR - Dados/amostra_sem_unha.txt")
df_usg = pd.read_fwf("FTIR - Dados/amostra_unha_sem_gel.txt")
df_gel = pd.read_fwf("FTIR - Dados/amostra_gel.txt")
df_ng = pd.read_fwf("FTIR - Dados/amostra_nosso_gel.txt")
df_GO = pd.read_fwf("FTIR - Dados/amostra_GO.txt")
df_rGO = pd.read_fwf("FTIR - Dados/amostra_rGO.txt")

# %%
lista_dfs =  [df_gel, df_ng, df_GO, df_rGO]

# %%
for i in lista_dfs:
    i['y'] =  i['y'] - df_usg['y'] + 100

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
df_asu.plot('x','y',legend=True, ax=ax1, kind = 'line', color = 'blue')
plt.title('Baseline - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
#plt.savefig('Gols e Público.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
df_usg.plot('x','y',legend=True, ax=ax2, kind = 'line', color = 'blue')
plt.title('Baseline - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
#plt.savefig('Gols e Público.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig3= plt.figure()
ax3 = fig3.add_subplot(111)
df_gel.plot('x','y',legend=True, ax=ax3, kind = 'line', color = 'blue')
plt.title('Baseline - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
#plt.savefig('Gols e Público.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig4= plt.figure()
ax4 = fig4.add_subplot(111)
df_ng.plot('x','y',legend=True, ax=ax4, kind = 'line', color = 'blue')
plt.title('Baseline - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
#plt.savefig('Gols e Público.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig5= plt.figure()
ax5 = fig5.add_subplot(111)
df_GO.plot('x','y',legend=True, ax=ax5, kind = 'line', color = 'blue')
plt.title('Baseline - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
#plt.savefig('Gols e Público.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig6= plt.figure()
ax6 = fig6.add_subplot(111)
df_rGO.plot('x','y',legend=True, ax=ax6, kind = 'line', color = 'blue')
plt.title('Baseline - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
#plt.savefig('Gols e Público.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig7= plt.figure()
ax7 = fig7.add_subplot(111)
df_gel.plot('x','y',legend=True, label = 'Gel não modificado', ax=ax7, kind = 'line', linewidth = 1, color = 'blue')
#df_ng.plot('x','y',legend=True, label = 'Gel não modificado 2', ax=ax7, kind = 'line', color = 'green')
df_GO.plot('x','y',legend=True, label = 'Gel modificado com GO', ax=ax7, kind = 'line', linewidth = 1, color = 'red')
#df_rGO.plot('x','y',legend=True, label = 'Gel modificado com rGO', ax=ax7, kind = 'line', color = 'purple')
plt.title('Gel controle e gel modificado com GO - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
plt.savefig('FTIR - Figuras/Gel controle e gel modificado com GO - FTIR.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig8= plt.figure()
ax8 = fig8.add_subplot(111)
df_gel.plot('x','y',legend=True, label = 'Gel não modificado', ax=ax8, kind = 'line', linewidth = 1, color = 'blue')
#df_ng.plot('x','y',legend=True, label = 'Gel não modificado 2', ax=ax7, kind = 'line', color = 'green')
#df_GO.plot('x','y',legend=True, label = 'Gel modificado com GO', ax=ax8, kind = 'line', color = 'red')
df_rGO.plot('x','y',legend=True, label = 'Gel modificado com rGO', ax=ax8, kind = 'line', linewidth = 1, color = 'purple')
plt.title('Gel controle e gel modificado com rGO - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
plt.savefig('FTIR - Figuras/Gel controle e gel modificado com rGO - FTIR.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig9= plt.figure()
ax9 = fig9.add_subplot(111)
df_gel.plot('x','y',legend=True, label = 'Gel não modificado', ax=ax9, kind = 'line', linewidth = 1, color = 'blue')
df_ng.plot('x','y',legend=True, label = 'Gel alternativo', ax=ax9, kind = 'line', linewidth = 1, color = 'green')
#df_GO.plot('x','y',legend=True, label = 'Gel modificado com GO', ax=ax8, kind = 'line', color = 'red')
#df_rGO.plot('x','y',legend=True, label = 'Gel modificado com rGO', ax=ax8, kind = 'line', color = 'purple')
plt.title('Diferença entre gel controle e gel alternativo - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
plt.savefig('FTIR - Figuras/Diferença entre gel controle e gel alternativo - FTIR.png', dpi=100, format='png', facecolor='white')
plt.show()

# %% [markdown]
# ## Análise do espectro do Óxido de Grafeno - FTIR

# %%
df_FTIR_GO = pd.read_fwf("FTIR - Dados/FTIR_GO.txt")

# %%
df_FTIR_GO['y'] = df_FTIR_GO['y'] - df_asu['y'] + 100

# %%
df_FTIR_GO.head(137)
# Out:
#               x          y
# 0    399.452262  33.184247
# 1    400.889141  33.681687
# 2    402.326019  32.849191
# 3    403.762898  32.134943
# 4    405.199776  31.338129
# ..          ...        ...
# 132  589.120242  38.121994
# 133  590.557121  38.196459
# 134  591.994000   8.306705
# 135  593.430878  38.483177
# 136  594.867757  38.534075
#
# [137 rows x 2 columns]

# %%
# Remoção de outlier
for i in range(len(df_FTIR_GO['y'])):
    y = df_FTIR_GO['y'][i]
    x = df_FTIR_GO['x'][i]
    if y < 20:
        print(y)
        print(x)
        print(i)
        df_FTIR_GO = df_FTIR_GO.drop([i], axis=0)
# Out:
# 8.306704999999994
# 591.994
# 134

# %%
df_FTIR_GO.head(137)
# Out:
#               x          y
# 0    399.452262  33.184247
# 1    400.889141  33.681687
# 2    402.326019  32.849191
# 3    403.762898  32.134943
# 4    405.199776  31.338129
# ..          ...        ...
# 132  589.120242  38.121994
# 133  590.557121  38.196459
# 135  593.430878  38.483177
# 136  594.867757  38.534075
# 137  596.304636  38.809530
#
# [137 rows x 2 columns]

# %%
fig10= plt.figure()
ax10 = fig10.add_subplot(111)
df_FTIR_GO.plot('x','y',legend=True, label = 'Amostra do GO', ax=ax10, kind = 'line', linewidth = 1, color = 'blue')
plt.title('Caracterização do Óxido de Grafeno - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
plt.savefig('FTIR - Figuras/Caracterização do Óxido de Grafeno - FTIR.png', dpi=100, format='png', facecolor='white')
plt.show()

# %% [markdown]
# ## Análise do Espectro após o teste de resistência química

# %%
df_cont1 = pd.read_fwf("FTIR - Dados/Controle1.txt")
df_apenas_unha1 = pd.read_fwf("FTIR - Dados/NADA1.txt")
df_NG1 = pd.read_fwf("FTIR - Dados/NG1.txt")
df_GO1 = pd.read_fwf("FTIR - Dados/GO1.txt")
df_rGO1 = pd.read_fwf("FTIR - Dados/rGO1.txt")

# %%
fig15 = plt.figure()
ax15 = fig15.add_subplot(111)
df_apenas_unha1.plot('x','y',legend=True, ax=ax15, kind = 'line', color = 'blue')
plt.title('Controle - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
#plt.savefig('Gols e Público.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig11 = plt.figure()
ax11 = fig11.add_subplot(111)
df_cont1.plot('x','y',legend=True, label = "Após a mudança de pH", ax=ax11, kind = 'line', linewidth = 1, color = 'red')
df_gel.plot('x','y',legend=True, label = "Antes da mudança de pH", ax=ax11, kind = 'line', linewidth = 1, color = 'blue')
plt.title('Influência do pH no gel controle - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
plt.savefig('FTIR - Figuras/Influência do pH no gel controle - FTIR.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig12 = plt.figure()
ax12 = fig12.add_subplot(111)
df_NG1.plot('x','y',legend=True, label = "Após a mudança de pH", ax=ax12, kind = 'line', linewidth = 1, color = 'red')
df_ng.plot('x','y',legend=True, label = "Antes da mudança de pH", ax=ax12, kind = 'line', linewidth = 1, color = 'blue')
plt.title('Influência do pH no gel alternativo - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
plt.savefig('FTIR - Figuras/Influência do pH no gel alternativo - FTIR.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig13 = plt.figure()
ax13 = fig13.add_subplot(111)
df_GO1.plot('x','y',legend=True, label = "Após a mudança de pH", ax=ax13, kind = 'line', linewidth = 1, color = 'red')
df_GO.plot('x','y',legend=True, label = "Antes da mudança de pH", ax=ax13, kind = 'line', linewidth = 1, color = 'blue')
plt.title('Influência do pH no gel modificado com GO - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
plt.savefig('FTIR - Figuras/Influência do pH no gel modificado com GO - FTIR.png', dpi=100, format='png', facecolor='white')
plt.show()

# %%
fig14 = plt.figure()
ax14 = fig14.add_subplot(111)
df_rGO1.plot('x','y',legend=True, label = "Após a mudança de pH", ax=ax14, kind = 'line', linewidth = 1, color = 'red')
df_rGO.plot('x','y',legend=True, label = "Antes da mudança de pH", ax=ax14, kind = 'line', linewidth = 1, color = 'blue')
plt.title('Influência do pH no gel modificado com rGO - FTIR')
plt.xlabel('Número de onda (1/cm)')
plt.ylabel('Transmitância (%)')
plt.gca().invert_xaxis()
plt.savefig('FTIR - Figuras/Influência do pH no gel modificado com rGO - FTIR.png', dpi=100, format='png', facecolor='white')
plt.show()
